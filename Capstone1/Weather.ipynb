# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
#import the weather files for top 20 origin airports of 2017 obtained from:
# https://mesonet.agron.iastate.edu/ASOS/
path = './Data/Weather/'
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_csv(f, parse_dates=['valid']) for f in all_files)
concatenated_df = pd.concat(df_from_each_file)

# %%
weather_df = concatenated_df

# %%
weather_df.head()
# Out:
#   station  network               valid  precip_in
# 0     LAX  CA_ASOS 2016-12-31 22:00:00        0.0
# 1     LAX  CA_ASOS 2016-12-31 23:00:00        0.0
# 2     LAX  CA_ASOS 2017-01-01 00:00:00        0.0
# 3     LAX  CA_ASOS 2017-01-01 01:00:00        0.0
# 4     LAX  CA_ASOS 2017-01-01 02:00:00        0.0

# %%
#export raw, concoctanated weather file for 2017 top 20 airports
weather_df.to_csv('./Data/Weather/2017Weather.csv', index = False, encoding = 'utf-8')

# %%
#import the 2017 Data and clean it
df = pd.read_csv('./Data/2017ALL.csv', parse_dates=['FlightDate'])


df = df.dropna(subset=['Tail_Number','DepTime','DepDelay','DepartureDelayGroups','TaxiOut',
                      'WheelsOff','WheelsOn','TaxiIn','ArrTime','ArrDelay','CRSElapsedTime',
                      'ActualElapsedTime','AirTime'])

df = df.fillna(0)

# %%
#Let's remove the features that will not be available for predicting flights
df = df[['Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
       'Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline',
       'Origin', 'OriginState', 'DestState', 'Dest', 'CRSDepTime', 'CRSArrTime', 'CRSElapsedTime',
       'ArrDelay', 'Distance', 'DistanceGroup',]]
df = df.reindex()

# %%
#since the DEP_TIME is presented as a float we need to convert it to a Timestamp
def convert_to_time (datatype):
    '''This method will take a float as input and returns a datetime.time object'''
    to_string = str(int(datatype))
    #check length of string and add leading zeros if lenght is less than 4
    while len(to_string) < 4:
        to_string = '0' + to_string
    #check if hour starts with 24 then change to 00
    if to_string[:2] == '24':
        to_string = '00' + to_string[2:]
    #obj = time.strptime(to_string, '%H%M')
    
    to_string = to_string[:2] + ':' + to_string[2:] 
    datetime = pd.to_datetime(to_string)
    datetime = pd.to_datetime(to_string, format='%H:%M')
    time = datetime.time()
    return time
    
    #datetime = time.strftime("%H:%M", obj)
    #return datetime
    
#We now need to create a new Timestamp column incorporating the information from FL_DATE and DEP_TIME
def combine_datetime (dataframe):
    '''This function will extract needed data from two columns and combine into a single Timestamp object'''
    year = dataframe[0].year
    month = dataframe[0].month
    day = dataframe[0].day
    hour = dataframe[1].hour
    minute = dataframe[1].minute
    second = dataframe[1].second
    
    datetime = pd.Timestamp(year, month, day, hour, minute, second)
    return datetime

# %%
combined = df[['FlightDate','CRSDepTime']]

# %%
#convert DEP_TIME to timestamp
combined['CRSDepTime'] = df.CRSDepTime.apply(convert_to_time)
# Out:
# /Users/dmitriykats/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#apply the combine_datetime function to optimized_df and create a new column 'FL_TIME'
df['FL_TIME'] = combined.apply(combine_datetime, axis=1)

# %%
df['FL_TIME_NEW'] = df.FL_TIME.apply(lambda x: x.replace(minute=0))

# %%
df.head()
# Out:
#    Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 0        2      5           6          6 2017-05-06                WN
# 1        2      5           6          6 2017-05-06                WN
# 2        2      5           6          6 2017-05-06                WN
# 3        2      5           6          6 2017-05-06                WN
# 4        2      5           6          6 2017-05-06                WN
#
#   Tail_Number  Flight_Number_Reporting_Airline Origin OriginState DestState  \
# 0      N7824A                             4652    SJC          CA        CA
# 1      N8522P                             4971    SJC          CA        CA
# 2      N8617E                             5113    SJC          CA        CA
# 3      N450WN                             5150    SJC          CA        CA
# 4      N498WN                             5711    SJC          CA        CA
#
#   Dest  CRSDepTime  CRSArrTime  CRSElapsedTime  ArrDelay  Distance  \
# 0  SAN         650         810            80.0       2.0     417.0
# 1  SAN        1710        1830            80.0      -7.0     417.0
# 2  SAN        1100        1220            80.0       0.0     417.0
# 3  SAN        2030        2150            80.0       1.0     417.0
# 4  SAN        1325        1445            80.0      -2.0     417.0
#
#    DistanceGroup             FL_TIME         FL_TIME_NEW
# 0              2 2017-05-06 06:50:00 2017-05-06 06:00:00
# 1              2 2017-05-06 17:10:00 2017-05-06 17:00:00
# 2              2 2017-05-06 11:00:00 2017-05-06 11:00:00
# 3              2 2017-05-06 20:30:00 2017-05-06 20:00:00
# 4              2 2017-05-06 13:25:00 2017-05-06 13:00:00

# %%
#combine the station name and datetime for easier / faster merging with flight data
weather_df_new = pd.DataFrame()
weather_df_new['combined'] = weather_df['station'] + weather_df['valid'].astype(str)
weather_df_new['precip'] = weather_df['precip_in']

# %%
weather_df_new.head()
# Out:
#                  combined  precip
# 0  LAX2016-12-31 22:00:00     0.0
# 1  LAX2016-12-31 23:00:00     0.0
# 2  LAX2017-01-01 00:00:00     0.0
# 3  LAX2017-01-01 01:00:00     0.0
# 4  LAX2017-01-01 02:00:00     0.0

# %%
sum_precip = []
for row in range(len(weather_df_new.precip) - 4):
    rows_sum = sum(weather_df_new.iloc[row:row + 4, 1].values)
    sum_precip.append(rows_sum)

# %%
sum_precip.insert(0,0)
sum_precip.insert(0,0)
sum_precip.insert(0,0)
sum_precip.insert(0,0)

# %%
weather_df_new['precip_sum'] = sum_precip

# %%
weather_df_new = weather_df_new.drop(columns=['precip'])

# %%
#do the same in the flight data 
df['combined'] =  df['Origin'] + df['FL_TIME_NEW'].astype(str)

# %%
df.head()
# Out:
#    Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 0        2      5           6          6 2017-05-06                WN
# 1        2      5           6          6 2017-05-06                WN
# 2        2      5           6          6 2017-05-06                WN
# 3        2      5           6          6 2017-05-06                WN
# 4        2      5           6          6 2017-05-06                WN
#
#   Tail_Number  Flight_Number_Reporting_Airline Origin OriginState  \
# 0      N7824A                             4652    SJC          CA
# 1      N8522P                             4971    SJC          CA
# 2      N8617E                             5113    SJC          CA
# 3      N450WN                             5150    SJC          CA
# 4      N498WN                             5711    SJC          CA
#
#             ...           Dest CRSDepTime  CRSArrTime  CRSElapsedTime  \
# 0           ...            SAN        650         810            80.0
# 1           ...            SAN       1710        1830            80.0
# 2           ...            SAN       1100        1220            80.0
# 3           ...            SAN       2030        2150            80.0
# 4           ...            SAN       1325        1445            80.0
#
#    ArrDelay  Distance  DistanceGroup             FL_TIME         FL_TIME_NEW  \
# 0       2.0     417.0              2 2017-05-06 06:50:00 2017-05-06 06:00:00
# 1      -7.0     417.0              2 2017-05-06 17:10:00 2017-05-06 17:00:00
# 2       0.0     417.0              2 2017-05-06 11:00:00 2017-05-06 11:00:00
# 3       1.0     417.0              2 2017-05-06 20:30:00 2017-05-06 20:00:00
# 4      -2.0     417.0              2 2017-05-06 13:25:00 2017-05-06 13:00:00
#
#                  combined
# 0  SJC2017-05-06 06:00:00
# 1  SJC2017-05-06 17:00:00
# 2  SJC2017-05-06 11:00:00
# 3  SJC2017-05-06 20:00:00
# 4  SJC2017-05-06 13:00:00
#
# [5 rows x 21 columns]

# %%
copy_df = df.copy()

# %%
copy_df.head()
# Out:
#    Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 0        2      5           6          6 2017-05-06                WN
# 1        2      5           6          6 2017-05-06                WN
# 2        2      5           6          6 2017-05-06                WN
# 3        2      5           6          6 2017-05-06                WN
# 4        2      5           6          6 2017-05-06                WN
#
#   Tail_Number  Flight_Number_Reporting_Airline Origin OriginState  \
# 0      N7824A                             4652    SJC          CA
# 1      N8522P                             4971    SJC          CA
# 2      N8617E                             5113    SJC          CA
# 3      N450WN                             5150    SJC          CA
# 4      N498WN                             5711    SJC          CA
#
#             ...           Dest CRSDepTime  CRSArrTime  CRSElapsedTime  \
# 0           ...            SAN        650         810            80.0
# 1           ...            SAN       1710        1830            80.0
# 2           ...            SAN       1100        1220            80.0
# 3           ...            SAN       2030        2150            80.0
# 4           ...            SAN       1325        1445            80.0
#
#    ArrDelay  Distance  DistanceGroup             FL_TIME         FL_TIME_NEW  \
# 0       2.0     417.0              2 2017-05-06 06:50:00 2017-05-06 06:00:00
# 1      -7.0     417.0              2 2017-05-06 17:10:00 2017-05-06 17:00:00
# 2       0.0     417.0              2 2017-05-06 11:00:00 2017-05-06 11:00:00
# 3       1.0     417.0              2 2017-05-06 20:30:00 2017-05-06 20:00:00
# 4      -2.0     417.0              2 2017-05-06 13:25:00 2017-05-06 13:00:00
#
#                  combined
# 0  SJC2017-05-06 06:00:00
# 1  SJC2017-05-06 17:00:00
# 2  SJC2017-05-06 11:00:00
# 3  SJC2017-05-06 20:00:00
# 4  SJC2017-05-06 13:00:00
#
# [5 rows x 21 columns]

# %%
weather_df_new.head()
# Out:
#                  combined  precip_sum
# 0  LAX2016-12-31 22:00:00         0.0
# 1  LAX2016-12-31 23:00:00         0.0
# 2  LAX2017-01-01 00:00:00         0.0
# 3  LAX2017-01-01 01:00:00         0.0
# 4  LAX2017-01-01 02:00:00         0.0

# %%
#mapping the weather data to the flight dataframe

# %%
weather_df_new = weather_df_new.set_index('combined')

# %%
weather_df_new.head()
# Out:
#                         precip_sum
# combined
# LAX2016-12-31 22:00:00         0.0
# LAX2016-12-31 23:00:00         0.0
# LAX2017-01-01 00:00:00         0.0
# LAX2017-01-01 01:00:00         0.0
# LAX2017-01-01 02:00:00         0.0

# %%
weather_dict = weather_df_new.to_dict()

# %%
weather_dict = weather_dict['precip_sum']

# %%
copy_df['precip_sum'] = copy_df.combined.map(weather_dict)

# %%
copy_df.head()
# Out:
#    Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 0        2      5           6          6 2017-05-06                WN
# 1        2      5           6          6 2017-05-06                WN
# 2        2      5           6          6 2017-05-06                WN
# 3        2      5           6          6 2017-05-06                WN
# 4        2      5           6          6 2017-05-06                WN
#
#   Tail_Number  Flight_Number_Reporting_Airline Origin OriginState    ...      \
# 0      N7824A                             4652    SJC          CA    ...
# 1      N8522P                             4971    SJC          CA    ...
# 2      N8617E                             5113    SJC          CA    ...
# 3      N450WN                             5150    SJC          CA    ...
# 4      N498WN                             5711    SJC          CA    ...
#
#   CRSDepTime CRSArrTime  CRSElapsedTime  ArrDelay  Distance  DistanceGroup  \
# 0        650        810            80.0       2.0     417.0              2
# 1       1710       1830            80.0      -7.0     417.0              2
# 2       1100       1220            80.0       0.0     417.0              2
# 3       2030       2150            80.0       1.0     417.0              2
# 4       1325       1445            80.0      -2.0     417.0              2
#
#               FL_TIME         FL_TIME_NEW                combined precip_sum
# 0 2017-05-06 06:50:00 2017-05-06 06:00:00  SJC2017-05-06 06:00:00        NaN
# 1 2017-05-06 17:10:00 2017-05-06 17:00:00  SJC2017-05-06 17:00:00        NaN
# 2 2017-05-06 11:00:00 2017-05-06 11:00:00  SJC2017-05-06 11:00:00        NaN
# 3 2017-05-06 20:30:00 2017-05-06 20:00:00  SJC2017-05-06 20:00:00        NaN
# 4 2017-05-06 13:25:00 2017-05-06 13:00:00  SJC2017-05-06 13:00:00        NaN
#
# [5 rows x 22 columns]

# %%
copy_df.Month.count()
# Out:
# 5579410

# %%
df.Month.count()
# Out:
# 5579410

# %%
weather_df_new.sort_values('precip_sum', ascending=False)
# Out:
#                         precip_sum
# combined
# IAH2017-08-27 08:00:00        4.86
# IAH2017-08-27 08:00:00        4.86
# IAH2017-08-27 08:00:00        4.86
# IAH2017-08-27 08:00:00        4.86
# IAH2017-08-27 02:00:00        4.83
# IAH2017-08-27 02:00:00        4.83
# IAH2017-08-27 02:00:00        4.83
# IAH2017-08-27 02:00:00        4.83
# IAH2017-08-27 03:00:00        4.52
# IAH2017-08-27 03:00:00        4.52
# IAH2017-08-27 03:00:00        4.52
# IAH2017-08-27 03:00:00        4.52
# IAH2017-08-08 04:00:00        4.28
# IAH2017-08-08 04:00:00        4.28
# IAH2017-08-08 04:00:00        4.28
# IAH2017-08-08 04:00:00        4.28
# IAH2017-08-27 17:00:00        4.23
# IAH2017-08-27 17:00:00        4.23
# IAH2017-08-27 17:00:00        4.23
# IAH2017-08-27 17:00:00        4.23
# IAH2017-08-27 01:00:00        4.13
# IAH2017-08-27 01:00:00        4.13
# IAH2017-08-27 01:00:00        4.13
# IAH2017-08-27 01:00:00        4.13
# IAH2017-08-27 16:00:00        4.09
# IAH2017-08-27 16:00:00        4.09
# IAH2017-08-27 16:00:00        4.09
# IAH2017-08-27 16:00:00        4.09
# IAH2017-08-27 07:00:00        4.06
# IAH2017-08-27 07:00:00        4.06
# ...                            ...
# PHX2017-12-19 01:00:00        0.00
# PHX2017-12-19 02:00:00        0.00
# PHX2017-12-19 03:00:00        0.00
# PHX2017-12-19 04:00:00        0.00
# PHX2017-12-19 05:00:00        0.00
# PHX2017-12-19 06:00:00        0.00
# PHX2017-12-19 07:00:00        0.00
# PHX2017-12-19 08:00:00        0.00
# PHX2017-12-19 09:00:00        0.00
# PHX2017-12-19 10:00:00        0.00
# PHX2017-12-19 11:00:00        0.00
# PHX2017-12-18 20:00:00        0.00
# PHX2017-12-18 19:00:00        0.00
# PHX2017-12-18 18:00:00        0.00
# PHX2017-12-18 09:00:00        0.00
# PHX2017-12-18 03:00:00        0.00
# PHX2017-12-18 04:00:00        0.00
# PHX2017-12-18 05:00:00        0.00
# PHX2017-12-18 06:00:00        0.00
# PHX2017-12-18 07:00:00        0.00
# PHX2017-12-18 08:00:00        0.00
# PHX2017-12-18 10:00:00        0.00
# PHX2017-12-18 17:00:00        0.00
# PHX2017-12-18 11:00:00        0.00
# PHX2017-12-18 12:00:00        0.00
# PHX2017-12-18 13:00:00        0.00
# PHX2017-12-18 14:00:00        0.00
# PHX2017-12-18 15:00:00        0.00
# PHX2017-12-18 16:00:00        0.00
# MSP2017-12-30 23:00:00        0.00
#
# [662156 rows x 1 columns]

# %%
#let's spotcheck the imported data
copy_df[(copy_df.Origin == 'IAH') & (copy_df.FL_TIME_NEW == '2017-08-27 08:00:00')]
# Out:
#          Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 3964668        3      8          27          7 2017-08-27                AA
# 4072547        3      8          27          7 2017-08-27                UA
# 4158826        3      8          27          7 2017-08-27                DL
# 4230635        3      8          27          7 2017-08-27                OO
#
#         Tail_Number  Flight_Number_Reporting_Airline Origin OriginState  \
# 3964668      N3HHAA                             1051    IAH          TX
# 4072547      N806UA                              527    IAH          TX
# 4158826      N955DL                             2258    IAH          TX
# 4230635      N898SK                             3529    IAH          TX
#
#            ...     CRSDepTime CRSArrTime  CRSElapsedTime  ArrDelay  Distance  \
# 3964668    ...            847       1005            78.0      13.0     224.0
# 4072547    ...            851       1129           158.0     281.0     925.0
# 4158826    ...            820       1119           119.0      59.0     689.0
# 4230635    ...            800       1018           198.0      10.0    1195.0
#
#          DistanceGroup             FL_TIME         FL_TIME_NEW  \
# 3964668              1 2017-08-27 08:47:00 2017-08-27 08:00:00
# 4072547              4 2017-08-27 08:51:00 2017-08-27 08:00:00
# 4158826              3 2017-08-27 08:20:00 2017-08-27 08:00:00
# 4230635              5 2017-08-27 08:00:00 2017-08-27 08:00:00
#
#                        combined precip_sum
# 3964668  IAH2017-08-27 08:00:00       4.86
# 4072547  IAH2017-08-27 08:00:00       4.86
# 4158826  IAH2017-08-27 08:00:00       4.86
# 4230635  IAH2017-08-27 08:00:00       4.86
#
# [4 rows x 22 columns]

# %%
#export the dataframe as a csv to model
copy_df.to_csv('./Data/2017NEW.csv', index = False, encoding = 'utf-8')
